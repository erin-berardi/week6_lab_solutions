# %%
import pandas as pd

# %%
top100 = pd.read_csv('top100.csv')

# %%
top100
# Out:
#                        song_title         artist
# 0                      Last Night  Morgan Wallen
# 1                         Flowers    Miley Cyrus
# 2                        Fast Car     Luke Combs
# 3   Like Crazy (Deep House Remix)          Jimin
# 4    Like Crazy (UK Garage Remix)          Jimin
# ..                            ...            ...
# 95                Whiskey Glasses  Morgan Wallen
# 96                       Face-off          Jimin
# 97                God Gave Me You  Blake Shelton
# 98               Tennessee Orange  Megan Moroney
# 99                      Calm Down           Rema
#
# [100 rows x 2 columns]

# %%
#top100.to_csv('top100.csv', index = False)

# %% [markdown]
# ## Import songs with features

# %%
song_features = pd.read_csv('spotify_features.csv')

# %%
song_features.head()
# Out:
#                             song_title     artists                     uri  \
# 0  Bohemian Rhapsody - Remastered 2011       Queen  7tFiyTwD0nx5a1eklYtX2J
# 1                       Roller Coaster  Danny Vera  5B5YKjgne3TZzNpMsN9aj1
# 2     Hotel California - 2013 Remaster      Eagles  40riOy7x9W7GXjyGp4pjAv
# 3                            Piano Man  Billy Joel  3FCto7hnn1shUyZL42YgfO
# 4                              Fix You    Coldplay  7LVHVU3tWfcxj5aiPFEW4Q
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.392   0.402    0    -9.961     0       0.0536       0.28800
# 1         0.401   0.383    9   -10.048     1       0.0279       0.51000
# 2         0.579   0.508    2    -9.484     1       0.0270       0.00574
# 3         0.334   0.472    0    -8.791     1       0.0277       0.60000
# 4         0.209   0.417    3    -8.740     1       0.0338       0.16400
#
#    instrumentalness  liveness  valence    tempo  duration_ms
# 0          0.000000    0.2430    0.228  143.883       354320
# 1          0.007800    0.1210    0.285   96.957       269986
# 2          0.000494    0.0575    0.609  147.125       391376
# 3          0.000004    0.3170    0.431  179.173       336093
# 4          0.001960    0.1130    0.124  138.178       295533

# %%
song_features['song_and_artist'] = song_features['song_title'] + ' - ' + song_features['artists']

# %%
song_features
# Out:
#                                 song_title        artists  \
# 0      Bohemian Rhapsody - Remastered 2011          Queen
# 1                           Roller Coaster     Danny Vera
# 2         Hotel California - 2013 Remaster         Eagles
# 3                                Piano Man     Billy Joel
# 4                                  Fix You       Coldplay
# ...                                    ...            ...
# 10138                    Wat Is Dan Liefde    Andre Hazes
# 10139                Zeker Niet De Laatste      John West
# 10140                     Amor, Amor, Amor    Andre Hazes
# 10141                Je Naam In De Sterren    Tino Martin
# 10142                  Die Ene Mooie Vrouw  Django Wagner
#
#                           uri  danceability  energy  key  loudness  mode  \
# 0      7tFiyTwD0nx5a1eklYtX2J         0.392   0.402    0    -9.961     0
# 1      5B5YKjgne3TZzNpMsN9aj1         0.401   0.383    9   -10.048     1
# 2      40riOy7x9W7GXjyGp4pjAv         0.579   0.508    2    -9.484     1
# 3      3FCto7hnn1shUyZL42YgfO         0.334   0.472    0    -8.791     1
# 4      7LVHVU3tWfcxj5aiPFEW4Q         0.209   0.417    3    -8.740     1
# ...                       ...           ...     ...  ...       ...   ...
# 10138  7lzSUHVotlqj0JSWIe5Q6D         0.240   0.506    0    -9.136     0
# 10139  0E7v2pwsFDb27wJtBRa3jI         0.714   0.902    7    -2.382     1
# 10140  4j8nikxlbjLnJPT7dvxTYs         0.468   0.550    8    -7.975     0
# 10141  0UjlMzjQtIA188YbpLoPAQ         0.599   0.356    2    -7.578     1
# 10142  6u8zWfpzojJlaifxcyBtFF         0.731   0.798    9    -5.066     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 0           0.0536       0.28800          0.000000    0.2430    0.228
# 1           0.0279       0.51000          0.007800    0.1210    0.285
# 2           0.0270       0.00574          0.000494    0.0575    0.609
# 3           0.0277       0.60000          0.000004    0.3170    0.431
# 4           0.0338       0.16400          0.001960    0.1130    0.124
# ...            ...           ...               ...       ...      ...
# 10138       0.0364       0.39000          0.000000    0.0612    0.195
# 10139       0.0433       0.30300          0.000000    0.3180    0.849
# 10140       0.0278       0.51900          0.008190    0.1700    0.417
# 10141       0.0268       0.34800          0.000000    0.1190    0.315
# 10142       0.0267       0.25300          0.000083    0.3350    0.867
#
#          tempo  duration_ms                              song_and_artist
# 0      143.883       354320  Bohemian Rhapsody - Remastered 2011 - Queen
# 1       96.957       269986                  Roller Coaster - Danny Vera
# 2      147.125       391376    Hotel California - 2013 Remaster - Eagles
# 3      179.173       336093                       Piano Man - Billy Joel
# 4      138.178       295533                           Fix You - Coldplay
# ...        ...          ...                                          ...
# 10138  188.508       216400              Wat Is Dan Liefde - Andre Hazes
# 10139  124.970       185260            Zeker Niet De Laatste - John West
# 10140  132.384       226333               Amor, Amor, Amor - Andre Hazes
# 10141   95.082       197547          Je Naam In De Sterren - Tino Martin
# 10142  101.991       204000          Die Ene Mooie Vrouw - Django Wagner
#
# [10143 rows x 16 columns]

# %%
song_features['song_title'] = song_features['song_title'].str.lower()

# %%
song_features.to_csv('song_features.csv')

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler
from matplotlib.lines import Line2D

# %%
cluster_features = song_features.drop(['song_title','artists','uri','song_and_artist'],axis=1)

# %%
cluster_features.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(cluster_features)
standard_cluster = scaler.transform(cluster_features)

standard_cluster = pd.DataFrame(standard_cluster,columns=cluster_features.columns)

# %%
pickle.dump(scaler, open('scaler.pkl', 'wb'))

# %%
standard_cluster.to_csv('std_features.csv')

# %%
import numpy as np
from sklearn.cluster import KMeans

K = range(2, 20)
inertia = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(standard_cluster)
    inertia.append(kmeans.inertia_)

import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=7, random_state=1234).fit(standard_cluster)
clusters = kmeans.predict(standard_cluster)
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0     488
# 1    2983
# 2    1674
# 3     830
# 4    2294
# 5    1573
# 6     301
# dtype: int64

# %%
import pickle
pickle.dump(kmeans, open('kmean.pkl', 'wb'))

# %%
cluster_df = pd.concat([song_features,pd.Series(clusters)],axis=1)

# %%
cluster_df = cluster_df.rename(columns={0:'cluster'})

# %%
cluster_df.to_csv('df_withclusters.csv')

# %%
kmeans.inertia_
# Out:
# 73803.54324382651

# %%
plt.figure(figsize=(10, 10))
plt.scatter(cluster_features['danceability'], cluster_features['valence'], c=clusters,alpha=0.25)
plt.show()

# %%
import seaborn as sns

correlation_matrix = cluster_features.corr()

sns.heatmap(correlation_matrix,annot=True)
plt.show()

# %%
#first part of the pipeline
import random 
new_song = input("Enter song: ")
new_artist = input("Enter artist: ")

if new_song in list(top100['song_title']):
    print(random.choice(list(top100['song_title'])))
else:
    print('No Recommendation')
# Out:
# Enter song: lskdfjkjjjj
# Enter artist: lsdkfjdlajf
# No Recommendation

# %%
secrets_file = open("/Users/erinberardi/Erin_dataV2-labs/SpotifySecret.txt","r")

# %%
string = secrets_file.read()

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line)>0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1]

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['cid'],client_secret=secrets_dict['cs']))

# %%
def features(track, artist):
    track_id = sp.search(q='artist:' + artist + ' track:' + track, type='track')
    uri = track_id["tracks"]["items"][0]['id']
    features = sp.audio_features(uri)
    return features

# %%
#I found out that if a song does not exist the total equals 0
new_song = input("Enter song: ").lower()
new_artist = input("Enter artist: ").lower()

test_entry = sp.search(q=new_song, type='track')
wrong_entry = test_entry["tracks"]["total"]
print(wrong_entry)
# Out:
# Enter song: dfjfsdl
# Enter artist: lsjfs
# 0

# %%
new_song = input("Enter song: ").lower()
new_artist = input("Enter artist: ").lower()

test_entry = sp.search(q=new_song, type='track')
wrong_entry = test_entry["tracks"]["total"] 

while wrong_entry == 0:
    print("Song does not exists, try another")
    new_song = input("Enter song: ").lower()
    new_artist = input("Enter artist: ").lower()
    test_entry = sp.search(q=new_song, type='track')
    wrong_entry = test_entry["tracks"]["total"]

if new_song in list(top100['song_title']):
    recommendation_hot = random.choice(list(top100['song_title']))
    while recommendation_hot == new_song:
            recommendation_hot = random.choice(list(top100['song_title']))
            print('Your recommendation:', recommendation_hot)
else:
    feature = features(new_song, new_artist)
    column = list(feature[0].keys())
    values = [list(feature[0].values())]
    df_new_song = pd.DataFrame(data = feature, columns = column)
    df_new_song = df_new_song.drop(['type','id','uri','track_href','analysis_url','time_signature'],axis=1)
    std_new_song = scaler.transform(df_new_song)
    new_cluster = kmeans.predict(std_new_song)
    df_cluster = cluster_df[cluster_df['cluster'] == list(new_cluster)[0]]

    print('Your recommendation:\n',random.choice(list(df_cluster['song_and_artist'])))
# Out:
# Enter song: flowers
# Enter artist: Miley cyrus
# Your recommendation:
#  Why'd You Only Call Me When You're High? - Arctic Monkeys
